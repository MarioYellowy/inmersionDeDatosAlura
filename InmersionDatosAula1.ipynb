# %% [markdown]
# <a href="https://colab.research.google.com/github/MarioYellowy/inmersionDeDatosAlura/blob/main/InmersionDatosAula1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

inmuebles = pd.read_csv('/content/drive/MyDrive/Inmersion Alura/inmuebles_bogota.csv')
inmuebles.head()
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Baños  Área              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor
# 0    $ 360.000.000
# 1    $ 670.000.000
# 2  $ 1.120.000.000
# ...

# %%
inmuebles.shape
# Out:
# (9520, 8)

# %%
inmuebles.columns
# Out:
# Index(['Tipo', 'Descripcion', 'Habitaciones', 'Baños', 'Área', 'Barrio', 'UPZ',
#        'Valor'],
#       dtype='object')

# %%
 columnas = {'Baños':'Banos', 'Área':'Area'}
 inmuebles = inmuebles.rename(columns=columnas)
 inmuebles.sample(10)
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 7287  Apartamento            Apartamento en venta en Cedritos             1
# 916   Apartamento  Apartamento en venta en Zona Noroccidental             1
# 1251  Apartamento       Apartamento en venta en Santa Barbara             2
# 6269  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 6459  Apartamento   Apartamento en venta en Chapinero Central             1
# 6739         Casa         Casa en venta en Zona Noroccidental             4
# 8128         Casa              Casa en venta en Puente Aranda             6
# 7609  Apartamento                Apartamento en venta en Bosa             3
# 8162  Apartamento            Apartamento en venta en Verbenal             2
# 2057  Apartamento             Apartamento en venta en Usaquén             3
#
#       Banos  Area              Barrio  \
# 7287      2    43            Cedritos
# 916       2    51  Zona Noroccidental
# ...

# %%
inmuebles.iloc[300]
# Out:
# Tipo                                Apartamento
# Descripcion     Apartamento en venta en Kennedy
# Habitaciones                                  2
# Banos                                         1
# Area                                         42
# Barrio                                  Kennedy
# UPZ                             Kennedy Central
# Valor                             $ 116.100.000
# Name: 300, dtype: object

# %%
inmuebles.Area.mean()
inmuebles.head()
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Banos  Area              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor
# 0    $ 360.000.000
# 1    $ 670.000.000
# 2  $ 1.120.000.000
# ...

# %%
inmuebles.Area.mean()
# Out:
# 146.66470588235293

# %%
inmuebles.sample(10)
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 7101  Apartamento                Apartamento en venta en Bosa             3
# 452   Apartamento            Apartamento en venta en Cedritos             2
# 3935  Apartamento  Apartamento en venta en Zona Noroccidental             2
# 1210  Apartamento            Apartamento en venta en Santa Fe             3
# 5589         Casa                    Casa en venta en Usaquén             5
# 6197        Local                  Local en venta en El Batán             2
# 6750  Apartamento                Apartamento en venta en Bosa             3
# 971   Apartamento             Apartamento en venta en Kennedy             3
# 3813         Casa                    Casa en venta en Usaquén             5
# 5346  Apartamento                Apartamento en venta en Bosa             3
#
#       Banos  Area              Barrio                                     UPZ  \
# ...

# %%
maximo = inmuebles['Area'].max()
datosMaximo = inmuebles.loc[inmuebles['Area'] == maximo].iloc[0]

# %%
print(datosMaximo)
# Out:
# Tipo                                Casa
# Descripcion     Casa en venta en Modelia
# Habitaciones                           4
# Banos                                  3
# Area                              166243
# Barrio                           Modelia
# UPZ                             Fontibón
# Valor                      $ 850.000.000
# Name: 7073, dtype: object

# %%
minimo = inmuebles['Area'].min()
datosMinimo = inmuebles.loc[inmuebles['Area'] == minimo].iloc[0]
print(datosMinimo)
# Out:
# Tipo                                      Apartamento
# Descripcion     Apartamento en venta en San Cristobal
# Habitaciones                                        3
# Banos                                               1
# Area                                                2
# Barrio                                  San Cristobal
# UPZ                                           Sosiego
# Valor                                   $ 180.000.000
# Name: 8401, dtype: object

# %% [markdown]
# Primero ordene los datos usando como referencia la columna 'Area', los acomode de mayor a menor

# %%
inmueblesOrdenado = inmuebles.sort_values('Area', ascending=False)
inmueblesOrdenado.head()
# Out:
#              Tipo                        Descripcion  Habitaciones  Banos  \
# 7073         Casa           Casa en venta en Modelia             4      3
# 6388  Apartamento  Apartamento en venta en Chapinero             3      5
# 3807  Apartamento  Apartamento en venta en Chapinero             3      5
# 4697        Finca   Finca en venta en Barrios Unidos             6      6
# 2279        Finca   Finca en venta en Barrios Unidos             6      6
#
#         Area          Barrio                                 UPZ  \
# 7073  166243         Modelia                            Fontibón
# 6388   15920       Chapinero  CHAPINERO: Pardo Rubio + Chapinero
# 3807   15920       Chapinero  CHAPINERO: Pardo Rubio + Chapinero
# 4697    8884  Barrios Unidos                           Los Andes
# 2279    8884  Barrios Unidos                           Los Andes
#
#                 Valor
# 7073    $ 850.000.000
# 6388  $ 1.250.000.000
# 3807  $ 1.250.000.000
# 4697  $ 1.000.000.000
# ...

# %%
inmueblesOrdenado.head(10)
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 7073         Casa                    Casa en venta en Modelia             4
# 6388  Apartamento           Apartamento en venta en Chapinero             3
# 3807  Apartamento           Apartamento en venta en Chapinero             3
# 4697        Finca            Finca en venta en Barrios Unidos             6
# 2279        Finca            Finca en venta en Barrios Unidos             6
# 9026         Casa                    Casa en venta en Usaquén             3
# 1860  Apartamento      Apartamento en venta en Barrios Unidos             3
# 1037  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 7891  Apartamento            Apartamento en venta en Engativa             2
# 7452  Apartamento            Apartamento en venta en Engativa             2
#
#       Banos    Area              Barrio                                 UPZ  \
# ...

# %%
inmueblesOrdenado = inmueblesOrdenado[:10]
print(inmueblesOrdenado)
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 7073         Casa                    Casa en venta en Modelia             4
# 6388  Apartamento           Apartamento en venta en Chapinero             3
# 3807  Apartamento           Apartamento en venta en Chapinero             3
# 4697        Finca            Finca en venta en Barrios Unidos             6
# 2279        Finca            Finca en venta en Barrios Unidos             6
# 9026         Casa                    Casa en venta en Usaquén             3
# 1860  Apartamento      Apartamento en venta en Barrios Unidos             3
# 1037  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 7891  Apartamento            Apartamento en venta en Engativa             2
# 7452  Apartamento            Apartamento en venta en Engativa             2
#
#       Banos    Area              Barrio                                 UPZ  \
# ...

# %% [markdown]
# Area mas pequenha

# %%
inmueblesOrdenado['Area'].min()
# Out:
# 4600

# %% [markdown]
# Area mas grande

# %%
inmueblesOrdenado['Area'].max()
# Out:
# 166243

# %% [markdown]
# Promedio

# %%
inmueblesOrdenado['Area'].mean()
# Out:
# 24314.0

# %% [markdown]
# Mediana

# %%
inmueblesOrdenado['Area'].median()
# Out:
# 7624.0

# %% [markdown]
# Conteo basandonos en el barrio

# %%
inmueblesOrdenado['Barrio'].value_counts()
# Out:
# Barrios Unidos        3
# Chapinero             2
# Engativa              2
# Modelia               1
# Usaquén               1
# Zona Noroccidental    1
# Name: Barrio, dtype: int64

# %% [markdown]
# Generacion de tabla

# %%
inmueblesOrdenado.Area.plot.bar()
# Out:
# <Axes: >
